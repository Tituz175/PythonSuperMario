# %% [markdown]
# # 1. Setup Mario

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py

# %%
# !pip show gym_super_mario_bros

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
done = True
for step in range(100000):
    if done:
        env.reset()
    obs, reward, terminated, truncated = env.step(env.action_space.sample())
    done = terminated or truncated
    env.render()
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 7
#       5     obs, reward, terminated, truncated = env.step(env.action_space.sample())
#       6     done = terminated or truncated
# ----> 7     env.render()
#       8 env.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\core.py:240, in Wrapper.render(self, mode, **kwargs)
#     239 def render(self, mode='human', **kwargs):
# --> 240     return self.env.render(mode, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\core.py:240, in Wrapper.render(self, mode, **kwargs)
#     239 def render(self, mode='human', **kwargs):
# --> 240     return self.env.render(mode, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nes_py\nes_env.py:386, in NESEnv.render(self, mode)
#     380         self.viewer = ImageViewer(
#     381             caption=caption,
#     382             height=SCREEN_HEIGHT,
#     383             width=SCREEN_WIDTH,
#     384         )
#     385     # show the screen on the image viewer
# --> 386     self.viewer.show(self.screen)
#     387 elif mode == 'rgb_array':
#     388     return self.screen
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nes_py\_image_viewer.py:148, in ImageViewer.show(self, frame)
#     140 image = self.pyglet.image.ImageData(
#     141     frame.shape[1],
#     142     frame.shape[0],
#    (...)
#     145     pitch=frame.shape[1]*-3
#     146 )
#     147 # send the image to the window
# --> 148 image.blit(0, 0, width=self._window.width, height=self._window.height)
#     149 self._window.flip()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyglet\image\__init__.py:901, in ImageData.blit(self, x, y, z, width, height)
#     900 def blit(self, x, y, z=0, width=None, height=None):
# --> 901     self.get_texture().blit(x, y, z, width, height)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyglet\image\__init__.py:832, in ImageData.get_texture(self, rectangle, force_rectangle)
#     829 def get_texture(self, rectangle=False, force_rectangle=False):
#     830     if (not self._current_texture or
#     831             (not self._current_texture._is_rectangle and force_rectangle)):
# --> 832         self._current_texture = self.create_texture(Texture, rectangle, force_rectangle)
#     833     return self._current_texture
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyglet\image\__init__.py:818, in ImageData.create_texture(self, cls, rectangle, force_rectangle)
#     795 """Create a texture containing this image.
#     796
#     797 If the image's dimensions are not powers of 2, a TextureRegion of
#    (...)
#     815 :rtype: cls or cls.region_class
#     816 """
#     817 internalformat = self._get_internalformat(self.format)
# --> 818 texture = cls.create(self.width, self.height, internalformat,
#     819                      rectangle, force_rectangle)
#     820 if self.anchor_x or self.anchor_y:
#     821     texture.anchor_x = self.anchor_x
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyglet\image\__init__.py:1464, in Texture.create(cls, width, height, internalformat, rectangle, force_rectangle, min_filter, mag_filter)
#    1462 glGenTextures(1, byref(id))
#    1463 glBindTexture(target, id.value)
# -> 1464 glTexParameteri(target, GL_TEXTURE_MIN_FILTER, min_filter)
#    1465 glTexParameteri(target, GL_TEXTURE_MAG_FILTER, mag_filter)
#    1467 blank = (GLubyte * (texture_width * texture_height * 4))()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyglet\gl\lib.py:87, in errcheck(result, func, arguments)
#      83 class GLException(Exception):
#      84     pass
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:

# %%
env.close
# Out:
# <bound method Wrapper.close of <JoypadSpace<TimeLimit<SuperMarioBrosEnv<SuperMarioBros-v0>>>>>

# %%
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the gamee
        env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())
    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# C:\Users\tobit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 10
#       8     env.reset()
#       9 # Do random actions
# ---> 10 state, reward, done, info = env.step(env.action_space.sample())
#      11 # Show the game on the screen
#      12 env.render()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nes_py\wrappers\joypad_space.py:74, in JoypadSpace.step(self, action)
#      59 """
#      60 Take a step using the given action.
#      61
#    (...)
#      71
#      72 """
#      73 # take the step and record the output
# ---> 74 return self.env.step(self._action_map[action])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\wrappers\time_limit.py:16, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16     observation, reward, done, info = self.env.step(action)
#      17     self._elapsed_steps += 1
#      18     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nes_py\nes_env.py:300, in NESEnv.step(self, action)
#     298 self.controllers[0][:] = action
#     299 # pass the action to the emulator as an unsigned byte
# --> 300 _LIB.Step(self._env)
#     301 # get the reward for this step
#     302 reward = float(self._get_reward())
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Preprocess Environment

# %%
# Install pytorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
# Install stable baselines for RL stuff
# !pip uninstall stable-baselines3[extra]
# !pip install stable-baselines3[extra]==1.3.0

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# C:\Users\tobit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 205 |
# |    iterations      | 1   |
# |    time_elapsed    | 2   |
# |    total_timesteps | 512 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 4.982692e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00164      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 241          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -2.81e-05    |
# |    value_loss           | 476          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 107           |
# |    iterations           | 3             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 2.7126633e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0804        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0831        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000501     |
# |    value_loss           | 1.05          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 4             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 1.3319077e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0108        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0783        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -3.57e-05     |
# |    value_loss           | 0.619         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 9.87167e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.0166      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.205       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000408   |
# |    value_loss           | 0.594       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 6.47828e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | -0.0659     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.29        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000173   |
# |    value_loss           | 0.603       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 7           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 7.50646e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.00188     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0921      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000163   |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 95            |
# |    iterations           | 8             |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 6.0313614e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00322      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.101         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000143     |
# |    value_loss           | 0.264         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 94            |
# |    iterations           | 9             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 1.4088582e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0027        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.123         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -1.55e-05     |
# |    value_loss           | 0.213         |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 10         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 8.9776e-06 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | -0.000207  |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.176      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.000242  |
# |    value_loss           | 0.317      |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 93            |
# |    iterations           | 11            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 1.3153884e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00171       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.209         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000392     |
# |    value_loss           | 0.367         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 12            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 7.1714167e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.000199      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.105         |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 0.197         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 13            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 1.2226286e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00368      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0613        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 0.156         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 14            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.3253302e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0074        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0729        |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000254     |
# |    value_loss           | 0.137         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 88            |
# |    iterations           | 15            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 3.4779077e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00595       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.138         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -6.56e-05     |
# |    value_loss           | 0.24          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 87            |
# |    iterations           | 16            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.8749968e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00291       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0693        |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000451     |
# |    value_loss           | 0.216         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 87           |
# |    iterations           | 17           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 2.595107e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0368       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 83.6         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 8.76e-05     |
# |    value_loss           | 182          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 87            |
# |    iterations           | 18            |
# |    time_elapsed         | 105           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 1.2614531e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00995       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 51.1          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 0.000264      |
# |    value_loss           | 183           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 86            |
# |    iterations           | 19            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 2.3203436e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0382        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.185         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000225     |
# |    value_loss           | 1.42          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 86           |
# |    iterations           | 20           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 3.481179e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0359      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.264        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00049     |
# |    value_loss           | 1.11         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 21           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 5.016802e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00883      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.129        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -9.59e-05    |
# |    value_loss           | 0.641        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 22           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 5.527283e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.000228    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.193        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -7.98e-05    |
# |    value_loss           | 0.419        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 85            |
# |    iterations           | 23            |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 3.5769772e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0111       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.321         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -8.82e-05     |
# |    value_loss           | 0.478         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 24           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 6.713206e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00262     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.141        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000145    |
# |    value_loss           | 0.485        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 84            |
# |    iterations           | 25            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 6.9395173e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00284       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.158         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000148     |
# |    value_loss           | 0.334         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 84            |
# |    iterations           | 26            |
# |    time_elapsed         | 158           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 1.0289019e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00226      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.165         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000206     |
# |    value_loss           | 0.33          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 27           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 2.639799e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00137     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.198        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000513    |
# |    value_loss           | 0.349        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 28           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 1.759315e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00385      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0956       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000329    |
# |    value_loss           | 0.198        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 29           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 14848        |
# | train/                  |              |
# |    approx_kl            | 3.845722e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00888      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.114        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000768    |
# |    value_loss           | 0.248        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 30           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 2.238003e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.000352     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.103        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000392    |
# |    value_loss           | 0.238        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 31           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 2.738065e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00395      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.212        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00044     |
# |    value_loss           | 0.393        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 32           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 4.313956e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.000249    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0652       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000688    |
# |    value_loss           | 0.14         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 33          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 16896       |
# | train/                  |             |
# |    approx_kl            | 1.99317e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0623      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 221         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000102    |
# |    value_loss           | 479         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 34           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 7.877825e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0613       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.114        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000203    |
# |    value_loss           | 1.46         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 35           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 2.971117e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.074        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000421    |
# |    value_loss           | 0.272        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 36            |
# |    time_elapsed         | 225           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.2082513e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0271       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0722        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000199     |
# |    value_loss           | 0.275         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 37            |
# |    time_elapsed         | 232           |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 1.9144383e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0143       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0987        |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00034      |
# |    value_loss           | 0.237         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 38            |
# |    time_elapsed         | 239           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 1.9029132e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00406      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.111         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000341     |
# |    value_loss           | 0.231         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 39            |
# |    time_elapsed         | 245           |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 2.7695205e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0214        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0667        |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000483     |
# |    value_loss           | 0.176         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 40           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 2.815167e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00501      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0935       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000436    |
# |    value_loss           | 0.195        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 80            |
# |    iterations           | 41            |
# |    time_elapsed         | 261           |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 1.6523874e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.000373     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.098         |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000262     |
# |    value_loss           | 0.198         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 80            |
# |    iterations           | 42            |
# |    time_elapsed         | 268           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 1.5355297e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.218         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0988        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000275     |
# |    value_loss           | 0.207         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 43           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 1.787371e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0373       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 300          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 3.7e-05      |
# |    value_loss           | 669          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 44           |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 5.233451e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0733       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.12         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -7.1e-05     |
# |    value_loss           | 0.542        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 80            |
# |    iterations           | 45            |
# |    time_elapsed         | 287           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 1.3239915e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.114         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0785        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000259     |
# |    value_loss           | 0.274         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 46            |
# |    time_elapsed         | 294           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 1.8869294e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0356       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0699        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000274     |
# |    value_loss           | 0.231         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 47          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 24064       |
# | train/                  |             |
# |    approx_kl            | 3.20751e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.022       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0524      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000419   |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 48            |
# |    time_elapsed         | 307           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.5319867e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0076       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0862        |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000384     |
# |    value_loss           | 0.21          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 49            |
# |    time_elapsed         | 314           |
# |    total_timesteps      | 25088         |
# | train/                  |               |
# |    approx_kl            | 1.9468018e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0148        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0484        |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000314     |
# |    value_loss           | 0.172         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 50            |
# |    time_elapsed         | 322           |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 2.0800275e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0266       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.062         |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000275     |
# |    value_loss           | 0.153         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 51            |
# |    time_elapsed         | 329           |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 3.0679163e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00836      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0498        |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000412     |
# |    value_loss           | 0.125         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 52            |
# |    time_elapsed         | 336           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 2.5292276e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0719       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.138         |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000315     |
# |    value_loss           | 0.274         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 53           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 27136        |
# | train/                  |              |
# |    approx_kl            | 6.553822e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00364     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.156        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000848    |
# |    value_loss           | 0.544        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 54            |
# |    time_elapsed         | 349           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 2.7750502e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00411       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0547        |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 0.129         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 55            |
# |    time_elapsed         | 356           |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 3.4489436e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0154       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0891        |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000405     |
# |    value_loss           | 0.146         |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 56         |
# |    time_elapsed         | 362        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 5.2694e-05 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.93      |
# |    explained_variance   | -0.0209    |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.0527     |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.000666  |
# |    value_loss           | 0.127      |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 78            |
# |    iterations           | 57            |
# |    time_elapsed         | 369           |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 7.8486744e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00762      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0736        |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.000682     |
# |    value_loss           | 0.174         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 78            |
# |    iterations           | 58            |
# |    time_elapsed         | 376           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 1.6184058e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.185         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 9.18          |
# |    n_updates            | 570           |
# |    policy_gradient_loss | 0.00011       |
# |    value_loss           | 18.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 78            |
# |    iterations           | 59            |
# |    time_elapsed         | 383           |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 1.3061683e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.046         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 200           |
# |    n_updates            | 580           |
# |    policy_gradient_loss | 8.68e-05      |
# |    value_loss           | 458           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 78            |
# |    iterations           | 60            |
# |    time_elapsed         | 390           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 3.3203978e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0107       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.135         |
# |    n_updates            | 590           |
# |    policy_gradient_loss | 1.49e-05      |
# |    value_loss           | 0.96          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 61           |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 3.252027e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0341       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.132        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000392    |
# |    value_loss           | 0.477        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 78            |
# |    iterations           | 62            |
# |    time_elapsed         | 404           |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 1.3554818e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0153       |
# |    learning_rate        | 1e-06         |
# ...
# |    explained_variance   | 0.508         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 306           |
# |    n_updates            | 19330         |
# |    policy_gradient_loss | -5.92e-05     |
# |    value_loss           | 633           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1935          |
# |    time_elapsed         | 18560         |
# |    total_timesteps      | 990720        |
# | train/                  |               |
# |    approx_kl            | 0.00091399334 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.28         |
# |    explained_variance   | 0.827         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 153           |
# |    n_updates            | 19340         |
# |    policy_gradient_loss | -0.00137      |
# |    value_loss           | 298           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1936          |
# |    time_elapsed         | 18570         |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00059886195 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.267        |
# |    explained_variance   | 0.84          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 108           |
# |    n_updates            | 19350         |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 326           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1937          |
# |    time_elapsed         | 18580         |
# |    total_timesteps      | 991744        |
# | train/                  |               |
# |    approx_kl            | 0.00036469894 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.263        |
# |    explained_variance   | 0.785         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 399           |
# |    n_updates            | 19360         |
# |    policy_gradient_loss | -0.000166     |
# |    value_loss           | 604           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 1938        |
# |    time_elapsed         | 18590       |
# |    total_timesteps      | 992256      |
# | train/                  |             |
# |    approx_kl            | 0.001711983 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 1e-06       |
# |    loss                 | 83.9        |
# |    n_updates            | 19370       |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 189         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1939          |
# |    time_elapsed         | 18601         |
# |    total_timesteps      | 992768        |
# | train/                  |               |
# |    approx_kl            | 0.00029686943 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.202        |
# |    explained_variance   | 0.646         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 576           |
# |    n_updates            | 19380         |
# |    policy_gradient_loss | -0.000852     |
# |    value_loss           | 667           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1940          |
# |    time_elapsed         | 18612         |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 0.00073860004 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.22         |
# |    explained_variance   | 0.873         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 104           |
# |    n_updates            | 19390         |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 244           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 1941         |
# |    time_elapsed         | 18622        |
# |    total_timesteps      | 993792       |
# | train/                  |              |
# |    approx_kl            | 7.507566e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.206       |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 172          |
# |    n_updates            | 19400        |
# |    policy_gradient_loss | -0.000252    |
# |    value_loss           | 340          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1942          |
# |    time_elapsed         | 18632         |
# |    total_timesteps      | 994304        |
# | train/                  |               |
# |    approx_kl            | 2.9008253e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.174        |
# |    explained_variance   | 0.369         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 269           |
# |    n_updates            | 19410         |
# |    policy_gradient_loss | -9.2e-05      |
# |    value_loss           | 975           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1943          |
# |    time_elapsed         | 18643         |
# |    total_timesteps      | 994816        |
# | train/                  |               |
# |    approx_kl            | 0.00028504978 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.177        |
# |    explained_variance   | 0.571         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 279           |
# |    n_updates            | 19420         |
# |    policy_gradient_loss | -0.000554     |
# |    value_loss           | 678           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1944          |
# |    time_elapsed         | 18653         |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 0.00058568374 |
# |    clip_fraction        | 0.00547       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.23         |
# |    explained_variance   | 0.877         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 80            |
# |    n_updates            | 19430         |
# |    policy_gradient_loss | -0.00189      |
# |    value_loss           | 170           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 1945        |
# |    time_elapsed         | 18664       |
# |    total_timesteps      | 995840      |
# | train/                  |             |
# |    approx_kl            | 0.001279985 |
# |    clip_fraction        | 0.0041      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.214      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 143         |
# |    n_updates            | 19440       |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 292         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1946          |
# |    time_elapsed         | 18674         |
# |    total_timesteps      | 996352        |
# | train/                  |               |
# |    approx_kl            | 5.1305513e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.177        |
# |    explained_variance   | 0.455         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.17e+03      |
# |    n_updates            | 19450         |
# |    policy_gradient_loss | -3.57e-05     |
# |    value_loss           | 951           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 1947        |
# |    time_elapsed         | 18685       |
# |    total_timesteps      | 996864      |
# | train/                  |             |
# |    approx_kl            | 0.000490266 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 181         |
# |    n_updates            | 19460       |
# |    policy_gradient_loss | -0.000747   |
# |    value_loss           | 337         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 1948         |
# |    time_elapsed         | 18695        |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0009817312 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 0.397        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 380          |
# |    n_updates            | 19470        |
# |    policy_gradient_loss | -0.000907    |
# |    value_loss           | 732          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1949          |
# |    time_elapsed         | 18706         |
# |    total_timesteps      | 997888        |
# | train/                  |               |
# |    approx_kl            | 0.00028015603 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.195        |
# |    explained_variance   | 0.838         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 107           |
# |    n_updates            | 19480         |
# |    policy_gradient_loss | -0.000339     |
# |    value_loss           | 226           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1950          |
# |    time_elapsed         | 18716         |
# |    total_timesteps      | 998400        |
# | train/                  |               |
# |    approx_kl            | 0.00026417605 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.226        |
# |    explained_variance   | 0.865         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 119           |
# |    n_updates            | 19490         |
# |    policy_gradient_loss | -0.000313     |
# |    value_loss           | 240           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 1951         |
# |    time_elapsed         | 18726        |
# |    total_timesteps      | 998912       |
# | train/                  |              |
# |    approx_kl            | 7.006468e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 113          |
# |    n_updates            | 19500        |
# |    policy_gradient_loss | -0.000171    |
# |    value_loss           | 277          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1952          |
# |    time_elapsed         | 18739         |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 0.00074895273 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.214        |
# |    explained_variance   | 0.724         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 160           |
# |    n_updates            | 19510         |
# |    policy_gradient_loss | -0.00105      |
# |    value_loss           | 328           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 53            |
# |    iterations           | 1953          |
# |    time_elapsed         | 18750         |
# |    total_timesteps      | 999936        |
# | train/                  |               |
# |    approx_kl            | 0.00038483576 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.197        |
# |    explained_variance   | 0.708         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 103           |
# |    n_updates            | 19520         |
# |    policy_gradient_loss | -0.000306     |
# |    value_loss           | 508           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 1954         |
# |    time_elapsed         | 18762        |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0012946421 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 365          |
# |    n_updates            | 19530        |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 469          |
# ------------------------------------------

# %%
model.save('thisisatestmodel')

# %% [markdown]
# # 4. Test it Out

# %%
# Load model
model = PPO.load('thisisatestmodel', clip_range=0.2)
# Out:
# C:\Users\tobit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\save_util.py:166: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
#   warnings.warn(
# C:\Users\tobit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\save_util.py:166: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
#   warnings.warn(
# C:\Users\tobit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\save_util.py:435: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)

# %%
# model = PPO.load('thisisatestmodel')
# model.clip_range = 0.2  # Or any value suitable for your use case
# model.set_env(env)  # Ensure the environment is properly set

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 6
#       3 # Loop through the game
#       4 while True:
# ----> 6     action, _ = model.predict(state)
#       7     state, reward, done, info = env.step(action)
#       8     env.render()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\base_class.py:552, in BaseAlgorithm.predict(self, observation, state, mask, deterministic)
#     535 def predict(
#     536     self,
#     537     observation: np.ndarray,
#    (...)
#     540     deterministic: bool = False,
#     541 ) -> Tuple[np.ndarray, Optional[np.ndarray]]:
#     542     """
#     543     Get the model's action(s) from an observation
#     544
#    (...)
#     550         (used in recurrent policies)
#     551     """
# --> 552     return self.policy.predict(observation, state, mask, deterministic)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\policies.py:336, in BasePolicy.predict(self, observation, state, mask, deterministic)
#     333 observation, vectorized_env = self.obs_to_tensor(observation)
#     335 with th.no_grad():
# --> 336     actions = self._predict(observation, deterministic=deterministic)
#     337 # Convert to numpy
#     338 actions = actions.cpu().numpy()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\policies.py:628, in ActorCriticPolicy._predict(self, observation, deterministic)
#     620 def _predict(self, observation: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     621     """
#     622     Get the action according to the policy for a given observation.
#     623
#    (...)
#     626     :return: Taken action according to the policy
#     627     """
# --> 628     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\distributions.py:79, in Distribution.get_actions(self, deterministic)
#      77 if deterministic:
#      78     return self.mode()
# ---> 79 return self.sample()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\distributions.py:284, in CategoricalDistribution.sample(self)
#     283 def sample(self) -> th.Tensor:
# --> 284     return self.distribution.sample()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\distributions\categorical.py:133, in Categorical.sample(self, sample_shape)
#     131     sample_shape = torch.Size(sample_shape)
#     132 probs_2d = self.probs.reshape(-1, self._num_events)
# --> 133 samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#     134 return samples_2d.reshape(self._extended_shape(sample_shape))
#
# KeyboardInterrupt:

# %%
env.close()
